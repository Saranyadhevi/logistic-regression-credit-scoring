# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in ./anaconda3/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in ./anaconda3/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in ./anaconda3/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in ./anaconda3/lib/python3.11/site-packages (from optuna) (1.4.39)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.11/site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in ./anaconda3/lib/python3.11/site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in ./anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in ./anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in ./anaconda3/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./anaconda3/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler,\
                                    PowerTransformer, TargetEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer

import optuna
from sklearn.feature_selection import SelectFromModel, SelectFwe, f_classif

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import sklearn.metrics as met

from sklearn.base import BaseEstimator, TransformerMixin

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

import sklearn
sklearn.set_config(transform_output="pandas")

GLOBAL_SEED = 1

# %%
df = pd.read_csv('/Users/saranyadheviranjith/Desktop/EMU/Machine Learning/credit_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   checking_acc_status       1000 non-null   object
#  1   duration                  1000 non-null   int64
#  2   cred_hist                 1000 non-null   object
#  3   purpose                   1000 non-null   object
#  4   loan_amt                  1000 non-null   int64
#  5   saving_acc_bonds          1000 non-null   object
#  6   present_employment_since  1000 non-null   object
#  7   installment_rate          1000 non-null   int64
#  8   personal_stat_gender      1000 non-null   object
#  9   other_debtors_guarantors  1000 non-null   object
#  10  present_residence_since   1000 non-null   int64
#  11  property                  1000 non-null   object
#  12  age                       1000 non-null   int64
#  13  other_installment_plans   1000 non-null   object
#  14  housing                   1000 non-null   object
#  15  num_curr_loans            1000 non-null   int64
#  16  job                       1000 non-null   object
#  17  num_people_provide_maint  1000 non-null   int64
#  18  telephone                 1000 non-null   object
#  19  is_foreign_worker         1000 non-null   object
#  20  target                    1000 non-null   object
# dtypes: int64(7), object(14)
# memory usage: 164.2+ KB

# %%
numeric_features = ['duration', 'loan_amt', 'installment_rate', 'present_residence_since', 'age', 'num_curr_loans', 
                    'num_people_provide_maint']
categorical_features = ['checking_acc_status', 'cred_hist', 'purpose', 'saving_acc_bonds', 'present_employment_since', 
                        'personal_stat_gender', 'other_debtors_guarantors', 'property', 'other_installment_plans', 
                        'housing', 'job', 'telephone', 'is_foreign_worker']

df[numeric_features] = df[numeric_features].apply(pd.to_numeric, errors='coerce', downcast='integer')
df[categorical_features] = df[categorical_features].astype('category')
df['target'] = np.where(df['target']=='good', 1, 0).astype('int8')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   checking_acc_status       1000 non-null   category
#  1   duration                  1000 non-null   int8
#  2   cred_hist                 1000 non-null   category
#  3   purpose                   1000 non-null   category
#  4   loan_amt                  1000 non-null   int16
#  5   saving_acc_bonds          1000 non-null   category
#  6   present_employment_since  1000 non-null   category
#  7   installment_rate          1000 non-null   int8
#  8   personal_stat_gender      1000 non-null   category
#  9   other_debtors_guarantors  1000 non-null   category
#  10  present_residence_since   1000 non-null   int8
#  11  property                  1000 non-null   category
#  12  age                       1000 non-null   int8
#  13  other_installment_plans   1000 non-null   category
#  14  housing                   1000 non-null   category
#  15  num_curr_loans            1000 non-null   int8
#  16  job                       1000 non-null   category
#  17  num_people_provide_maint  1000 non-null   int8
#  18  telephone                 1000 non-null   category
#  19  is_foreign_worker         1000 non-null   category
#  20  target                    1000 non-null   int8
# dtypes: category(13), int16(1), int8(7)
# memory usage: 24.0 KB

# %%
for cat in categorical_features:
    print(df[cat].value_counts(1))
    print('-----------------')
# Out:
# checking_acc_status
# no_cheking_acc    0.394
# below_0           0.274
# below_200         0.269
# above:200         0.063
# Name: proportion, dtype: float64
# -----------------
# cred_hist
# curr_loans_paid_duly            0.530
# risky_acc_or_curr_loan_other    0.293
# delay_in_past                   0.088
# paid_duly_this_bank             0.049
# no_loan_or_paid_duly_other      0.040
# Name: proportion, dtype: float64
# -----------------
# purpose
# radio_tv               0.280
# car_new                0.234
# furniture_equipment    0.181
# car_used               0.103
# business               0.097
# education              0.050
# repairs                0.022
# domestic_applience     0.012
# others                 0.012
# retraining             0.009
# Name: proportion, dtype: float64
# -----------------
# saving_acc_bonds
# below_100                0.603
# unknown_no_saving_acc    0.183
# below_500                0.103
# below_1000               0.063
# above_1000               0.048
# Name: proportion, dtype: float64
# -----------------
# present_employment_since
# below_4y      0.339
# above_7y      0.253
# below_7y      0.174
# below_1y      0.172
# unemployed    0.062
# Name: proportion, dtype: float64
# -----------------
# personal_stat_gender
# male:single                   0.548
# female:divorced_or_married    0.310
# male:married_or_widowed       0.092
# male:divorced                 0.050
# Name: proportion, dtype: float64
# -----------------
# other_debtors_guarantors
# none            0.907
# guarantor       0.052
# co_applicant    0.041
# Name: proportion, dtype: float64
# -----------------
# property
# car_or_other                     0.332
# real_estate                      0.282
# life_insurance_or_aggreements    0.232
# unknown_or_no_property           0.154
# Name: proportion, dtype: float64
# -----------------
# other_installment_plans
# none     0.814
# bank     0.139
# store    0.047
# Name: proportion, dtype: float64
# -----------------
# housing
# own         0.713
# rent        0.179
# for_free    0.108
# Name: proportion, dtype: float64
# -----------------
# job
# skilled_official           0.630
# unskilled_resident         0.200
# management_or_self_emp     0.148
# unemployed_non_resident    0.022
# Name: proportion, dtype: float64
# -----------------
# telephone
# no     0.596
# yes    0.404
# Name: proportion, dtype: float64
# -----------------
# is_foreign_worker
# yes    0.963
# no     0.037
# Name: proportion, dtype: float64
# -----------------

# %%
df.target.value_counts(1)
# Out:
# target
# 1    0.7
# 0    0.3
# Name: proportion, dtype: float64

# %%
X = df[numeric_features+categorical_features]
y = df['target'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=GLOBAL_SEED, stratify=y)

# %%
en = TargetEncoder(random_state=GLOBAL_SEED)
X_train_encoded = en.fit_transform(X_train[categorical_features],y_train)
X_test_encoded = en.transform(X_test[categorical_features])
X_train_preprocessed = pd.concat([X_train[numeric_features], X_train_encoded], axis=1)
X_test_preprocessed = pd.concat([X_test[numeric_features], X_test_encoded], axis=1)

model = LogisticRegression(penalty=None, random_state=GLOBAL_SEED)
model.fit(X_train_preprocessed, y_train)

y_train_pred_proba = model.predict_proba(X_train_preprocessed)[:, 1]
y_pred_proba = model.predict_proba(X_test_preprocessed)[:, 1]

train_auc = met.roc_auc_score(y_train, y_train_pred_proba)
test_auc = met.roc_auc_score(y_test, y_pred_proba)
print(f"AUC-ROC on train data: {round(train_auc, 3)}")
print(f"AUC-ROC on test data: {round(test_auc, 3)}")

print(f"Gini score: {round(test_auc*2-1, 3)}")
# Out:
# AUC-ROC on train data: 0.712
# AUC-ROC on test data: 0.705
# Gini score: 0.41

# %%
cats = np.concatenate(en.categories_).reshape(-1,1)
ends = np.concatenate(en.encodings_).reshape(-1,1)

features = []
for feature in categorical_features:
    n_cat = df[feature].nunique()
    [features.append(feature) for i in range(n_cat)]

comb = np.concatenate((cats, ends), axis = 1)
en_df = pd.DataFrame(comb, index=features).reset_index()
en_df.columns = ['feature','category', 'encoding_value']
en_df.head()
# Out:
#                feature              category encoding_value
# 0  checking_acc_status             above:200       0.783003
# 1  checking_acc_status               below_0       0.517783
# 2  checking_acc_status             below_200       0.611332
# 3  checking_acc_status        no_cheking_acc       0.881219
# 4            cred_hist  curr_loans_paid_duly       0.676906

# %%
en_df[en_df.feature.isin(['present_employment_since', 'purpose'])]
# Out:
#                      feature             category encoding_value
# 9                    purpose             business        0.62774
# 10                   purpose              car_new       0.626822
# 11                   purpose             car_used       0.868949
# 12                   purpose   domestic_applience       0.610256
# 13                   purpose            education       0.580854
# 14                   purpose  furniture_equipment       0.676873
# 15                   purpose               others       0.572246
# 16                   purpose             radio_tv       0.777456
# 17                   purpose              repairs       0.668863
# 18                   purpose           retraining            1.0
# 24  present_employment_since             above_7y       0.741904
# 25  present_employment_since             below_1y       0.600839
# 26  present_employment_since             below_4y       0.705406
# 27  present_employment_since             below_7y       0.784563
# 28  present_employment_since           unemployed       0.568561

# %%
fpr, tpr, thresholds = met.roc_curve(y_test, y_pred_proba)
roc_auc = met.auc(fpr, tpr)


plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='Navy', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
feature_coefficients = model.coef_[0]
feature_names = list(X_train_preprocessed.columns)
feature_names.append('intercept')

intercept = model.intercept_[0]
fimp = pd.DataFrame(list(feature_coefficients) + [intercept],
                    index=feature_names, columns=['value']).reset_index()
fimp = fimp.sort_values('value', ascending=True)

plt.figure(figsize=(6,12))
plt.barh(fimp.iloc[:20]['index'], fimp.iloc[:20]['value'], color='green')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.title('Feature Coefficients for Logistic Regression')
plt.show()

# %%
numeric_features = X.select_dtypes(exclude='category').columns
purpose = ['purpose']
other_categorical_features = X.drop('purpose', axis=1).select_dtypes('category').columns

# %%
class LogOddsEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, smoothing_factor=1):
        self.feature_log_odds = {}
        self.smoothing_factor = smoothing_factor

    def fit(self, X, y=None):
        for column in X.columns:
        
            Xy = pd.concat([X,y], axis=1)
            events = Xy.groupby(column)['target'].mean()
            category_log_odds = np.log((events + self.smoothing_factor) / 
                                       (Xy['target'].mean() + 2 * self.smoothing_factor))
            
            self.feature_log_odds[column] = category_log_odds.to_dict()
            
        return self

    def transform(self, X, y=None):
        X_encoded = X.copy()
        for column in X.columns:
           
            X_encoded[column] = X[column].map(self.feature_log_odds[column])
        return X_encoded
    
    def get_feature_names_out():
        pass

# %%
def objective(trial):
    
    
    params = {
        'class_weight':'balanced',
        'C': trial.suggest_float("C", 1e-3, 1000),
        'l1_ratio': trial.suggest_float("l1_ratio", 0, 1),
        'penalty':'elasticnet',
        'solver': 'saga',
        'random_state': GLOBAL_SEED
    }
    
    min_frequency = trial.suggest_categorical("min_frequency", [0.01, 0.012, 0.015, 0.020, 0.052])
    smoothing = trial.suggest_float("smoothing", 1e-4, 10) 
    multiplier = trial.suggest_float("multiplier", 0, 1)
    
    scaler_options = {
        'StandardScaler': StandardScaler(),
        'RobustScaler': RobustScaler(),
        'MinMaxScaler': MinMaxScaler(feature_range=(-1,1))
    }
    
    cat_encoding_options = {
        'ohe': OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop='if_binary'),'target_encoder': TargetEncoder(random_state=GLOBAL_SEED),
        'lg_encoder': LogOddsEncoder(smoothing)
    }
    
    purpose_encoding_options = {
        'ohe': OneHotEncoder(min_frequency=min_frequency, sparse_output=False, handle_unknown='ignore'),
        'target_encoder': TargetEncoder(random_state=GLOBAL_SEED),
        'lg_encoder': LogOddsEncoder(smoothing)
    }

    selected_scaler = trial.suggest_categorical("scaler", ['StandardScaler','RobustScaler', 'MinMaxScaler'])
    selected_cat_encoder = trial.suggest_categorical('cat_encoder', ['ohe', 'target_encoder', 'lg_encoder'])
    selected_purpose_encoder = trial.suggest_categorical('purpose_encoder', ['target_encoder', 'lg_encoder'])
        
    model = LogisticRegression(**params)
    
    num_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value=0)),('scaler', scaler_options[selected_scaler])])
    
    if selected_cat_encoder == 'ohe':
    
        other_cat_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                 ('encoder', cat_encoding_options[selected_cat_encoder])])    
    else:
        
        other_cat_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                        ('encoder', cat_encoding_options[selected_cat_encoder]),
                                     ('scaler', scaler_options[selected_scaler])])
        
    if selected_purpose_encoder == 'ohe':

        purpose_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                        ('encoder', purpose_encoding_options[selected_purpose_encoder])])
    else:
        
        purpose_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                        ('encoder', purpose_encoding_options[selected_purpose_encoder]),
                               ('scaler', scaler_options[selected_scaler])])
    
    transformer = ColumnTransformer(transformers=[
        ('num_p', num_p, numeric_features),
        ('other_cat_p', other_cat_p, other_categorical_features), 
        ('purpose_p', purpose_p, purpose)
    ])

    
   
    pipeline = Pipeline(steps=[
        ('transformer', transformer),
        ('selector', SelectFromModel(model,threshold=f'{multiplier}*median', max_features=None)),
        ('model', model)
    ])

    means = cross_val_score(estimator=pipeline,X=X_train,y=y_train, cv=10, scoring='roc_auc')
    
    return np.mean(means)

# %%
def tune(objective):
    study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(
                            seed=GLOBAL_SEED))
    study.optimize(objective, n_trials=100, show_progress_bar=True)

    params = study.best_params
    best_score = study.best_value
    print(f"Best score: {best_score} \nOptimized parameters: {params}")
    return study

# %%
study = tune(objective)
# Out:
# [I 2024-04-21 12:22:28,499] A new study created in memory with name: no-name-37489253-19f0-4a5d-a152-d6023d08be17
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2024-04-21 12:22:28,916] Trial 0 finished with value: 0.767593378729556 and parameters: {'C': 417.0225876805693, 'l1_ratio': 0.7203244934421581, 'min_frequency': 0.012, 'smoothing': 3.4556727143577732, 'multiplier': 0.39676747423066994, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 0 with value: 0.767593378729556.
# [I 2024-04-21 12:22:29,399] Trial 1 finished with value: 0.7658264827871062 and parameters: {'C': 558.6902697559232, 'l1_ratio': 0.14038693859523377, 'min_frequency': 0.015, 'smoothing': 8.763903884045153, 'multiplier': 0.8946066635038473, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 0 with value: 0.767593378729556.
# [I 2024-04-21 12:22:30,151] Trial 2 finished with value: 0.7604900841570241 and parameters: {'C': 691.8774220733594, 'l1_ratio': 0.31551563100606295, 'min_frequency': 0.052, 'smoothing': 7.481681727232956, 'multiplier': 0.2804439920644052, 'scaler': 'StandardScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 0 with value: 0.767593378729556.
# [I 2024-04-21 12:22:30,586] Trial 3 finished with value: 0.7783236861579765 and parameters: {'C': 678.835854104358, 'l1_ratio': 0.21162811600005904, 'min_frequency': 0.02, 'smoothing': 5.893096438479152, 'multiplier': 0.6997583600209312, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:31,300] Trial 4 finished with value: 0.7565796795493268 and parameters: {'C': 944.5948113960574, 'l1_ratio': 0.5865550405019929, 'min_frequency': 0.01, 'smoothing': 1.653625435749616, 'multiplier': 0.9275085803960339, 'scaler': 'RobustScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:31,720] Trial 5 finished with value: 0.7739242299947795 and parameters: {'C': 895.8863223098487, 'l1_ratio': 0.4280911898712949, 'min_frequency': 0.01, 'smoothing': 4.499176343586057, 'multiplier': 0.5783896143871318, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:32,240] Trial 6 finished with value: 0.7476532696179948 and parameters: {'C': 885.9422133686752, 'l1_ratio': 0.35726976000249977, 'min_frequency': 0.02, 'smoothing': 9.97322877222976, 'multiplier': 0.17234050834532855, 'scaler': 'RobustScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:32,695] Trial 7 finished with value: 0.7653162055335969 and parameters: {'C': 124.27183770120273, 'l1_ratio': 0.01988013383979559, 'min_frequency': 0.02, 'smoothing': 5.5282645046597905, 'multiplier': 0.8420308923596057, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:33,204] Trial 8 finished with value: 0.7608245323175593 and parameters: {'C': 807.1053885135835, 'l1_ratio': 0.38786064406417176, 'min_frequency': 0.01, 'smoothing': 1.2135224230617994, 'multiplier': 0.044551878544761725, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:33,830] Trial 9 finished with value: 0.7580180074232576 and parameters: {'C': 203.29403136775582, 'l1_ratio': 0.2523257445703234, 'min_frequency': 0.02, 'smoothing': 2.398553606699947, 'multiplier': 0.49376971426872995, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:34,257] Trial 10 finished with value: 0.775037001554639 and parameters: {'C': 345.5192893234821, 'l1_ratio': 0.9457764691684007, 'min_frequency': 0.012, 'smoothing': 6.357779664513287, 'multiplier': 0.6927683454457213, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:34,681] Trial 11 finished with value: 0.775037001554639 and parameters: {'C': 348.19916837014296, 'l1_ratio': 0.9894948837925434, 'min_frequency': 0.012, 'smoothing': 6.257825484927423, 'multiplier': 0.694366492875478, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:35,106] Trial 12 finished with value: 0.775037001554639 and parameters: {'C': 604.6527596380802, 'l1_ratio': 0.9919751786903798, 'min_frequency': 0.012, 'smoothing': 7.07803402284726, 'multiplier': 0.6897275881647301, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:35,519] Trial 13 finished with value: 0.7713085929656891 and parameters: {'C': 336.47624057578565, 'l1_ratio': 0.7459726223957042, 'min_frequency': 0.015, 'smoothing': 4.656521036971222, 'multiplier': 0.7678082626112835, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:35,936] Trial 14 finished with value: 0.774044413338917 and parameters: {'C': 660.1986292121678, 'l1_ratio': 0.5751058206532658, 'min_frequency': 0.052, 'smoothing': 7.917167499958023, 'multiplier': 0.5732869574676153, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:36,414] Trial 15 finished with value: 0.7780212199613348 and parameters: {'C': 471.62804559449336, 'l1_ratio': 0.7618580451288952, 'min_frequency': 0.02, 'smoothing': 5.983402983489946, 'multiplier': 0.6910543676408818, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:36,866] Trial 16 finished with value: 0.7736970576593218 and parameters: {'C': 749.7799465074107, 'l1_ratio': 0.7643909037278425, 'min_frequency': 0.02, 'smoothing': 3.670132628357069, 'multiplier': 0.4350310754802603, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:37,216] Trial 17 finished with value: 0.7698014249901043 and parameters: {'C': 485.926198203636, 'l1_ratio': 0.1884079613461448, 'min_frequency': 0.02, 'smoothing': 5.1194311312125445, 'multiplier': 0.5950878809120177, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:37,635] Trial 18 finished with value: 0.7606914414543618 and parameters: {'C': 510.67108174740036, 'l1_ratio': 0.009690137305307406, 'min_frequency': 0.02, 'smoothing': 8.773354424223342, 'multiplier': 0.976957461708731, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:38,070] Trial 19 finished with value: 0.7779892379974415 and parameters: {'C': 67.92718895954687, 'l1_ratio': 0.8627829414148797, 'min_frequency': 0.02, 'smoothing': 0.040353178749738206, 'multiplier': 0.8026860540969616, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:38,455] Trial 20 finished with value: 0.7670526970978161 and parameters: {'C': 221.4468211482373, 'l1_ratio': 0.5324849149042299, 'min_frequency': 0.02, 'smoothing': 6.006437265744016, 'multiplier': 0.3332115801078983, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:38,954] Trial 21 finished with value: 0.7776397310646695 and parameters: {'C': 120.12225557302898, 'l1_ratio': 0.8478116219740304, 'min_frequency': 0.02, 'smoothing': 0.6473117414852133, 'multiplier': 0.8286864546420236, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 3 with value: 0.7783236861579765.
# [I 2024-04-21 12:22:39,466] Trial 22 finished with value: 0.7795649592409232 and parameters: {'C': 7.050713607256398, 'l1_ratio': 0.6490236020314732, 'min_frequency': 0.02, 'smoothing': 3.4315283978136284, 'multiplier': 0.7764378246855298, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:39,967] Trial 23 finished with value: 0.7784072981981104 and parameters: {'C': 9.706184114351174, 'l1_ratio': 0.6563688345539588, 'min_frequency': 0.02, 'smoothing': 3.5426983271650085, 'multiplier': 0.7136785005783299, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:40,456] Trial 24 finished with value: 0.7777233431048034 and parameters: {'C': 56.06598566135457, 'l1_ratio': 0.6569280106832344, 'min_frequency': 0.015, 'smoothing': 3.061437110881374, 'multiplier': 0.7486945597592619, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:41,135] Trial 25 finished with value: 0.7540559727393197 and parameters: {'C': 228.86528672177025, 'l1_ratio': 0.49790311142318716, 'min_frequency': 0.052, 'smoothing': 4.211337223639829, 'multiplier': 0.6334472715111669, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:41,617] Trial 26 finished with value: 0.7598297928486608 and parameters: {'C': 3.0044307973962106, 'l1_ratio': 0.4621013595138169, 'min_frequency': 0.02, 'smoothing': 2.5891157928886885, 'multiplier': 0.9816020589115578, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:42,105] Trial 27 finished with value: 0.7750714216054659 and parameters: {'C': 7.9998559640801545, 'l1_ratio': 0.6337312040799633, 'min_frequency': 0.02, 'smoothing': 3.69394417944065, 'multiplier': 0.5085505784043136, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:42,527] Trial 28 finished with value: 0.7623750121904348 and parameters: {'C': 172.27971244648094, 'l1_ratio': 0.11368097637304642, 'min_frequency': 0.02, 'smoothing': 2.394897191796196, 'multiplier': 0.8904264612989318, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:43,271] Trial 29 finished with value: 0.775495935565665 and parameters: {'C': 300.5977342386627, 'l1_ratio': 0.6809079522941713, 'min_frequency': 0.02, 'smoothing': 3.1475994807504635, 'multiplier': 0.5058975510402657, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:43,774] Trial 30 finished with value: 0.753397545850376 and parameters: {'C': 408.74637628514006, 'l1_ratio': 0.57946937441734, 'min_frequency': 0.015, 'smoothing': 5.153151655767995, 'multiplier': 0.6364575547825462, 'scaler': 'RobustScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:44,208] Trial 31 finished with value: 0.7778091063981137 and parameters: {'C': 797.5524375728725, 'l1_ratio': 0.7921216656678798, 'min_frequency': 0.02, 'smoothing': 5.663085154636638, 'multiplier': 0.7378863885232861, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:44,644] Trial 32 finished with value: 0.7774617507185185 and parameters: {'C': 605.2433965632827, 'l1_ratio': 0.8506441589821327, 'min_frequency': 0.02, 'smoothing': 6.674232032242741, 'multiplier': 0.8381827065342944, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:45,119] Trial 33 finished with value: 0.7779956917569715 and parameters: {'C': 486.6551119026606, 'l1_ratio': 0.7015508535735435, 'min_frequency': 0.02, 'smoothing': 3.7640607040834912, 'multiplier': 0.6519125192055156, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:45,594] Trial 34 finished with value: 0.7658264827871062 and parameters: {'C': 718.7140852493943, 'l1_ratio': 0.8009508006854144, 'min_frequency': 0.052, 'smoothing': 7.932480852410428, 'multiplier': 0.891229886443634, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:46,028] Trial 35 finished with value: 0.7778948696914242 and parameters: {'C': 270.3427939074036, 'l1_ratio': 0.6259694874678728, 'min_frequency': 0.01, 'smoothing': 4.504923537592981, 'multiplier': 0.7609125331895148, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:46,496] Trial 36 finished with value: 0.7729958925406013 and parameters: {'C': 417.76510337695527, 'l1_ratio': 0.5428967344118247, 'min_frequency': 0.02, 'smoothing': 1.8898609738628873, 'multiplier': 0.5576935927231035, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:47,040] Trial 37 finished with value: 0.7625954439326055 and parameters: {'C': 94.60487805713925, 'l1_ratio': 0.27291950856576086, 'min_frequency': 0.02, 'smoothing': 5.223587580713298, 'multiplier': 0.39962801045220864, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:47,703] Trial 38 finished with value: 0.7459047310359862 and parameters: {'C': 644.7978075098954, 'l1_ratio': 0.720995547843446, 'min_frequency': 0.01, 'smoothing': 4.222295578154298, 'multiplier': 0.930691739436972, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:48,191] Trial 39 finished with value: 0.7639848666509865 and parameters: {'C': 973.6820906338787, 'l1_ratio': 0.41718658865089114, 'min_frequency': 0.012, 'smoothing': 7.135964012636313, 'multiplier': 0.7933960783931248, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:48,650] Trial 40 finished with value: 0.7780212199613348 and parameters: {'C': 861.0517173911146, 'l1_ratio': 0.4897084491153736, 'min_frequency': 0.02, 'smoothing': 5.789225573513428, 'multiplier': 0.7164245409493802, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:49,085] Trial 41 finished with value: 0.7750947985566525 and parameters: {'C': 863.9711510465266, 'l1_ratio': 0.07689960737894619, 'min_frequency': 0.02, 'smoothing': 5.81891441821339, 'multiplier': 0.6754204061009225, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:49,547] Trial 42 finished with value: 0.7781048320014686 and parameters: {'C': 874.8569697937521, 'l1_ratio': 0.3548084577874706, 'min_frequency': 0.02, 'smoothing': 4.966605384818341, 'multiplier': 0.7035919978013365, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:50,007] Trial 43 finished with value: 0.774674587102807 and parameters: {'C': 925.0493575831727, 'l1_ratio': 0.33764867881891186, 'min_frequency': 0.02, 'smoothing': 4.887317261072743, 'multiplier': 0.5958264238802721, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:50,459] Trial 44 finished with value: 0.779189637270031 and parameters: {'C': 799.9248549595532, 'l1_ratio': 0.20644392770206468, 'min_frequency': 0.02, 'smoothing': 4.096695772782786, 'multiplier': 0.7278000971811103, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:50,903] Trial 45 finished with value: 0.7674987235897819 and parameters: {'C': 802.8766152340509, 'l1_ratio': 0.19696494889719574, 'min_frequency': 0.015, 'smoothing': 2.9865912352550046, 'multiplier': 0.8654125990059837, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:51,593] Trial 46 finished with value: 0.7655710573265948 and parameters: {'C': 998.7633385295197, 'l1_ratio': 0.2835242251718496, 'min_frequency': 0.01, 'smoothing': 4.138835291054502, 'multiplier': 0.08637200271760848, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:52,110] Trial 47 finished with value: 0.7619071863329452 and parameters: {'C': 755.5756984441377, 'l1_ratio': 0.20745629161247614, 'min_frequency': 0.012, 'smoothing': 1.8512776195870493, 'multiplier': 0.8024374106054805, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:52,496] Trial 48 finished with value: 0.7649562291686984 and parameters: {'C': 755.1444135320604, 'l1_ratio': 0.35879047927631663, 'min_frequency': 0.052, 'smoothing': 4.007402631900054, 'multiplier': 0.7347629975745774, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:52,939] Trial 49 finished with value: 0.775146428632893 and parameters: {'C': 842.5877670247717, 'l1_ratio': 0.23831037264976954, 'min_frequency': 0.02, 'smoothing': 3.3601929680501894, 'multiplier': 0.546728922418654, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:53,376] Trial 50 finished with value: 0.7732919049777129 and parameters: {'C': 907.3340288261899, 'l1_ratio': 0.0988310272172145, 'min_frequency': 0.02, 'smoothing': 4.743125836589053, 'multiplier': 0.4589215350773154, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:53,801] Trial 51 finished with value: 0.7780233712145115 and parameters: {'C': 706.1253472688392, 'l1_ratio': 0.1463632296051185, 'min_frequency': 0.02, 'smoothing': 6.700189315616188, 'multiplier': 0.6932068126831296, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:54,229] Trial 52 finished with value: 0.7746767383559836 and parameters: {'C': 697.8682079408763, 'l1_ratio': 0.15479143495737777, 'min_frequency': 0.02, 'smoothing': 6.45906639802927, 'multiplier': 0.6383874029031773, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:54,656] Trial 53 finished with value: 0.7781048320014686 and parameters: {'C': 548.448082077936, 'l1_ratio': 0.04818678017443778, 'min_frequency': 0.02, 'smoothing': 5.3681791158504835, 'multiplier': 0.7121869984370649, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:55,169] Trial 54 finished with value: 0.7783535168686931 and parameters: {'C': 552.2268216018715, 'l1_ratio': 0.07556777041775217, 'min_frequency': 0.02, 'smoothing': 5.372080751994181, 'multiplier': 0.777623496014076, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:55,601] Trial 55 finished with value: 0.7653697000292571 and parameters: {'C': 642.1173921790465, 'l1_ratio': 0.2891553780676732, 'min_frequency': 0.02, 'smoothing': 4.520942067932058, 'multiplier': 0.9359139321559988, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:56,031] Trial 56 finished with value: 0.7784435826683571 and parameters: {'C': 602.7745996460048, 'l1_ratio': 0.39085875973202583, 'min_frequency': 0.02, 'smoothing': 2.637023093631464, 'multiplier': 0.7797683979396289, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:56,467] Trial 57 finished with value: 0.7708047694717097 and parameters: {'C': 550.2765234085372, 'l1_ratio': 0.036087773387003766, 'min_frequency': 0.012, 'smoothing': 2.4928543461918458, 'multiplier': 0.7737373747994754, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:56,913] Trial 58 finished with value: 0.7759180114389301 and parameters: {'C': 606.0807523672497, 'l1_ratio': 0.41557494824785673, 'min_frequency': 0.02, 'smoothing': 1.460050074988435, 'multiplier': 0.858981368662453, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:57,418] Trial 59 finished with value: 0.7594910421817722 and parameters: {'C': 582.0739697475219, 'l1_ratio': 0.2298232371622595, 'min_frequency': 0.015, 'smoothing': 2.6862531655078294, 'multiplier': 0.8202636367325001, 'scaler': 'RobustScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'lg_encoder'}. Best is trial 22 with value: 0.7795649592409232.
# [I 2024-04-21 12:22:57,885] Trial 60 finished with value: 0.7796507225342337 and parameters: {'C': 46.408193408375155, 'l1_ratio': 0.16907049615820327, 'min_frequency': 0.02, 'smoothing': 3.4603749238823163, 'multiplier': 0.779590744956754, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:22:58,393] Trial 61 finished with value: 0.7781478570650022 and parameters: {'C': 27.919311893596404, 'l1_ratio': 0.16022563096342707, 'min_frequency': 0.02, 'smoothing': 3.4859902574869386, 'multiplier': 0.7642288253922004, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:22:58,929] Trial 62 finished with value: 0.7706805704549757 and parameters: {'C': 149.69200750294254, 'l1_ratio': 0.11525397945327787, 'min_frequency': 0.02, 'smoothing': 2.1635974237303377, 'multiplier': 0.2477942619189738, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:22:59,377] Trial 63 finished with value: 0.7794813472007893 and parameters: {'C': 84.04360094501367, 'l1_ratio': 0.18300574404828354, 'min_frequency': 0.02, 'smoothing': 2.8211793701800767, 'multiplier': 0.7749306196029047, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:22:59,820] Trial 64 finished with value: 0.7794813472007893 and parameters: {'C': 57.356962325301915, 'l1_ratio': 0.0734587604046499, 'min_frequency': 0.02, 'smoothing': 2.8337460679024296, 'multiplier': 0.790819233426493, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:00,279] Trial 65 finished with value: 0.7759158601857535 and parameters: {'C': 75.71226778299308, 'l1_ratio': 0.17449314799599064, 'min_frequency': 0.02, 'smoothing': 2.896253948778553, 'multiplier': 0.8487306018466335, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:00,756] Trial 66 finished with value: 0.7758107356138529 and parameters: {'C': 35.71633429667936, 'l1_ratio': 0.00083319715032798, 'min_frequency': 0.052, 'smoothing': 0.9301820742798674, 'multiplier': 0.9028684504168973, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:01,223] Trial 67 finished with value: 0.7777405531302168 and parameters: {'C': 112.86564582826992, 'l1_ratio': 0.6248149166715049, 'min_frequency': 0.02, 'smoothing': 3.3007624810536997, 'multiplier': 0.6634882248404915, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:01,691] Trial 68 finished with value: 0.7779956917569715 and parameters: {'C': 154.6005023079284, 'l1_ratio': 0.12668340395786376, 'min_frequency': 0.02, 'smoothing': 3.7756823746718813, 'multiplier': 0.6096354463608163, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:02,214] Trial 69 finished with value: 0.7648145332927943 and parameters: {'C': 194.55311169578397, 'l1_ratio': 0.3193162433152632, 'min_frequency': 0.02, 'smoothing': 2.768491691781941, 'multiplier': 0.8157968120982632, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:02,706] Trial 70 finished with value: 0.7776440335710229 and parameters: {'C': 34.64428485025045, 'l1_ratio': 0.5416416435692295, 'min_frequency': 0.01, 'smoothing': 2.120415799992762, 'multiplier': 0.7361245191500824, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 60 with value: 0.7796507225342337.
# [I 2024-04-21 12:23:03,172] Trial 71 finished with value: 0.7797386370807208 and parameters: {'C': 85.08441326427396, 'l1_ratio': 0.06359193560684018, 'min_frequency': 0.02, 'smoothing': 3.9495914342492133, 'multiplier': 0.7872054898640072, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:03,623] Trial 72 finished with value: 0.7795649592409232 and parameters: {'C': 80.29427295619396, 'l1_ratio': 0.05894057579532253, 'min_frequency': 0.02, 'smoothing': 3.1787051231199057, 'multiplier': 0.7932006565761763, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:04,075] Trial 73 finished with value: 0.7652003246958128 and parameters: {'C': 92.59209641231466, 'l1_ratio': 0.06541411151946709, 'min_frequency': 0.02, 'smoothing': 3.9708863691809024, 'multiplier': 0.9533721670597649, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:04,516] Trial 74 finished with value: 0.7761688475593316 and parameters: {'C': 51.09514625489713, 'l1_ratio': 0.09384574776284746, 'min_frequency': 0.02, 'smoothing': 3.2430011817131774, 'multiplier': 0.8654258603380783, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:04,999] Trial 75 finished with value: 0.779483498453966 and parameters: {'C': 124.91034585599523, 'l1_ratio': 0.03354866911845727, 'min_frequency': 0.02, 'smoothing': 2.2865812441086186, 'multiplier': 0.7939371198392489, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:05,387] Trial 76 finished with value: 0.7629258764205442 and parameters: {'C': 135.19870755549178, 'l1_ratio': 0.036660730349928145, 'min_frequency': 0.02, 'smoothing': 2.2505132101222705, 'multiplier': 0.8304451873562763, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:05,850] Trial 77 finished with value: 0.7659316073590068 and parameters: {'C': 80.70070157809829, 'l1_ratio': 0.012242644191503137, 'min_frequency': 0.02, 'smoothing': 3.0770585289219206, 'multiplier': 0.9010720208332808, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:06,503] Trial 78 finished with value: 0.7506945679423119 and parameters: {'C': 257.0567788315746, 'l1_ratio': 0.04757473858418004, 'min_frequency': 0.015, 'smoothing': 1.595628325411139, 'multiplier': 0.7986967005745215, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:06,981] Trial 79 finished with value: 0.7780620937716919 and parameters: {'C': 116.56163748450261, 'l1_ratio': 0.12289089301976244, 'min_frequency': 0.02, 'smoothing': 3.5406190730807454, 'multiplier': 0.7318213921823263, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:07,471] Trial 80 finished with value: 0.7768807689439355 and parameters: {'C': 1.1435779513675044, 'l1_ratio': 0.18465917295308965, 'min_frequency': 0.012, 'smoothing': 4.314348346820432, 'multiplier': 0.7520189193917559, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:07,967] Trial 81 finished with value: 0.7794813472007893 and parameters: {'C': 53.85873940810582, 'l1_ratio': 0.09201100970717335, 'min_frequency': 0.02, 'smoothing': 2.7539286996027816, 'multiplier': 0.7841612907582838, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:08,438] Trial 82 finished with value: 0.7767541318402681 and parameters: {'C': 63.58425263244501, 'l1_ratio': 0.08539075765242767, 'min_frequency': 0.02, 'smoothing': 3.7371661601898802, 'multiplier': 0.877302176432583, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:08,906] Trial 83 finished with value: 0.7774574482121652 and parameters: {'C': 98.81197427734486, 'l1_ratio': 0.06052238506557592, 'min_frequency': 0.02, 'smoothing': 2.966268483334341, 'multiplier': 0.8288639819395102, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:09,357] Trial 84 finished with value: 0.7795671104940999 and parameters: {'C': 183.3527322598179, 'l1_ratio': 0.13199785213484594, 'min_frequency': 0.02, 'smoothing': 1.8492502492696339, 'multiplier': 0.7895391127418891, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:09,799] Trial 85 finished with value: 0.7794813472007893 and parameters: {'C': 185.82022765540114, 'l1_ratio': 0.02785314300079445, 'min_frequency': 0.02, 'smoothing': 1.7503772363653076, 'multiplier': 0.7929063180779241, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:10,292] Trial 86 finished with value: 0.7631828794667186 and parameters: {'C': 170.08865678372254, 'l1_ratio': 0.14245104634350636, 'min_frequency': 0.052, 'smoothing': 1.4154068783712868, 'multiplier': 0.6754519064508108, 'scaler': 'MinMaxScaler', 'cat_encoder': 'ohe', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:10,728] Trial 87 finished with value: 0.7773910461974449 and parameters: {'C': 54.13591397446744, 'l1_ratio': 0.10705876614413926, 'min_frequency': 0.02, 'smoothing': 1.1447101806285431, 'multiplier': 0.7566212864452169, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:11,169] Trial 88 finished with value: 0.7759158601857534 and parameters: {'C': 217.933098813749, 'l1_ratio': 0.16780850366830768, 'min_frequency': 0.02, 'smoothing': 1.9301790325042782, 'multiplier': 0.8445229816366591, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:11,607] Trial 89 finished with value: 0.779483498453966 and parameters: {'C': 131.5870638443701, 'l1_ratio': 0.09259584182568915, 'min_frequency': 0.01, 'smoothing': 2.3985435292440442, 'multiplier': 0.8120521504915026, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:11,964] Trial 90 finished with value: 0.7616160500697007 and parameters: {'C': 135.71732652195462, 'l1_ratio': 0.13402443181198026, 'min_frequency': 0.01, 'smoothing': 2.2966333209319783, 'multiplier': 0.9113043978269793, 'scaler': 'MinMaxScaler', 'cat_encoder': 'target_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:12,409] Trial 91 finished with value: 0.7793977351606556 and parameters: {'C': 25.455234164700045, 'l1_ratio': 0.0823987284536713, 'min_frequency': 0.01, 'smoothing': 2.4081258697034094, 'multiplier': 0.7982659362480133, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:12,848] Trial 92 finished with value: 0.77650114446669 and parameters: {'C': 93.7232557130899, 'l1_ratio': 0.020891617717848587, 'min_frequency': 0.01, 'smoothing': 2.7901426901451396, 'multiplier': 0.8794358092283723, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:13,292] Trial 93 finished with value: 0.7793955839074789 and parameters: {'C': 67.62475086668813, 'l1_ratio': 0.11026272140857402, 'min_frequency': 0.01, 'smoothing': 2.0542502667208744, 'multiplier': 0.8145221123064077, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:13,727] Trial 94 finished with value: 0.7794813472007893 and parameters: {'C': 112.74472711381736, 'l1_ratio': 0.057999081396998706, 'min_frequency': 0.02, 'smoothing': 2.531661474474903, 'multiplier': 0.7657902641008022, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:14,179] Trial 95 finished with value: 0.7761688475593316 and parameters: {'C': 157.4627060741321, 'l1_ratio': 0.8998446647588749, 'min_frequency': 0.02, 'smoothing': 3.2689482515092236, 'multiplier': 0.850427248093333, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:14,639] Trial 96 finished with value: 0.7687531910255454 and parameters: {'C': 50.06285971075901, 'l1_ratio': 0.2537390993979345, 'min_frequency': 0.01, 'smoothing': 3.147943303599514, 'multiplier': 0.7820537391756128, 'scaler': 'StandardScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:15,259] Trial 97 finished with value: 0.7517083818560439 and parameters: {'C': 21.274720775294938, 'l1_ratio': 0.09317380104453296, 'min_frequency': 0.02, 'smoothing': 2.85816278678581, 'multiplier': 0.7147902944906231, 'scaler': 'RobustScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:15,703] Trial 98 finished with value: 0.7797364858275441 and parameters: {'C': 250.93409564620657, 'l1_ratio': 0.22801796579181588, 'min_frequency': 0.02, 'smoothing': 3.476272454996657, 'multiplier': 0.8137425206280613, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# [I 2024-04-21 12:23:16,148] Trial 99 finished with value: 0.779395583907479 and parameters: {'C': 243.82210318868073, 'l1_ratio': 0.22611025501404042, 'min_frequency': 0.02, 'smoothing': 9.905589920232856, 'multiplier': 0.8166262063262759, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}. Best is trial 71 with value: 0.7797386370807208.
# Best score: 0.7797386370807208
# Optimized parameters: {'C': 85.08441326427396, 'l1_ratio': 0.06359193560684018, 'min_frequency': 0.02, 'smoothing': 3.9495914342492133, 'multiplier': 0.7872054898640072, 'scaler': 'MinMaxScaler', 'cat_encoder': 'lg_encoder', 'purpose_encoder': 'target_encoder'}

# %%
params = study.best_params
params
# Out:
# {'C': 85.08441326427396,
#  'l1_ratio': 0.06359193560684018,
#  'min_frequency': 0.02,
#  'smoothing': 3.9495914342492133,
#  'multiplier': 0.7872054898640072,
#  'scaler': 'MinMaxScaler',
#  'cat_encoder': 'lg_encoder',
#  'purpose_encoder': 'target_encoder'}

# %%
model_params = {
    'class_weight': 'balanced',
    'C': params['C'],
    'l1_ratio': params['l1_ratio'],
    'penalty': 'elasticnet',
    'solver': 'saga',
    'random_state': GLOBAL_SEED
}

scaler_options = {
    'StandardScaler': StandardScaler(),
    'RobustScaler': RobustScaler(),
    'MinMaxScaler': MinMaxScaler(feature_range=(-1,1))
}

cat_encoding_options = {
    'ohe': OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop='if_binary'),
    'target_encoder': TargetEncoder(random_state=GLOBAL_SEED),
    'lg_encoder': LogOddsEncoder(params['smoothing'])
}
purpose_encoding_options = {
    'ohe': OneHotEncoder(min_frequency=params['min_frequency'], sparse_output=False, handle_unknown='ignore'),
    'target_encoder': TargetEncoder(random_state=GLOBAL_SEED),
    'lg_encoder': LogOddsEncoder(params['smoothing'])
}


model = LogisticRegression(**model_params)

num_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value=0)),
                                      ('scaler', scaler_options[params['scaler']])])

if params['cat_encoder'] == 'ohe':

    other_cat_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
             ('encoder', cat_encoding_options[selected_cat_encoder])])    
else:

    other_cat_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                    ('encoder', cat_encoding_options[params['cat_encoder']]),
                                 ('scaler', scaler_options[params['scaler']])])
if params['purpose_encoder'] == 'ohe':

    purpose_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                    ('encoder', purpose_encoding_options[params['purpose_encoder']])])
else:

    purpose_p = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='not_given')), 
                    ('encoder', purpose_encoding_options[params['purpose_encoder']]),
                               ('scaler', scaler_options[params['scaler']])])

transformer = ColumnTransformer(transformers=[
    ('num_p', num_p, numeric_features),
    ('other_cat_p', other_cat_p, other_categorical_features), 
    ('purpose_p', purpose_p, purpose)
])


# Full Pipeline
pipeline = Pipeline(steps=[
    ('transformer', transformer),
    ('selector', SelectFromModel(model, threshold=f"{params['multiplier']}*median", max_features=None)),
    ('model', model)
])   
# Fit the model
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num_p',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler(feature_range=(-1,
#                                                                                                1)))]),
#                                                   Index(['duration', 'loan_amt', 'installment_rate', 'present_residence_since',
#        'age', 'num_curr_loans', 'num_people_provide_maint'],
#       dtype='object')),
#                                                  ('other_cat_...
#                  SelectFromModel(estimator=LogisticRegression(C=85.08441326427396,
#                                                               class_weight='balanced',
#                                                               l1_ratio=0.06359193560684018,
#                                                               penalty='elasticnet',
#                                                               random_state=1,
#                                                               solver='saga'),
#                                  threshold='0.7872054898640072*median')),
#                 ('model',
#                  LogisticRegression(C=85.08441326427396,
#                                     class_weight='balanced',
#                                     l1_ratio=0.06359193560684018,
#                                     penalty='elasticnet', random_state=1,
#                                     solver='saga'))])

# %%
y_train_pred_proba = pipeline.predict_proba(X_train)[:,1]
y_pred_proba = pipeline.predict_proba(X_test)[:,1]

# %%
fpr, tpr, thresholds = met.roc_curve(y_train, y_train_pred_proba)
roc_auc = met.auc(fpr, tpr)


plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='Navy', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
print('Average Cross-Validation Gini Score:', round(study.best_value * 2 - 1, 2))
print('Gini Score on train set:', round(roc_auc * 2 - 1, 2))
# Out:
# Average Cross-Validation Gini Score: 0.56
# Gini Score on train set: 0.64

# %%
fpr, tpr, thresholds = met.roc_curve(y_test, y_pred_proba)
roc_auc = met.auc(fpr, tpr)


plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='Navy', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
print('Average Cross-Validation Gini Score:', round(study.best_value * 2 - 1, 2))
print('Gini Score on test set:', round(roc_auc * 2 - 1, 2))
# Out:
# Average Cross-Validation Gini Score: 0.56
# Gini Score on test set: 0.62

# %%
feature_importances = pipeline[-1].coef_[0]
feature_names = list(pipeline[:-1].transform(X_train).columns)
feature_names = ['_'.join(name.split('__')[1:]) for name in feature_names]
feature_names.append('intercept')

intercept = pipeline[-1].intercept_[0]
fimp = pd.DataFrame(list(feature_importances) + [intercept], index=feature_names, columns=['value']).reset_index()
fimp['significancy'] = fimp.value.abs()
fimp = fimp.sort_values('significancy', ascending=True)

plt.figure(figsize=(6,12))
plt.barh(fimp['index'], fimp['value'], color='green')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.title('Feature Importances for Logistic Regression')
plt.show()

# %%
fimp.shape
# Out:
# (14, 3)

# %%
fimp
# Out:
#                        index     value  significancy
# 6           saving_acc_bonds  0.322401      0.322401
# 7   present_employment_since  0.352734      0.352734
# 13                 intercept -0.355579      0.355579
# 3                        age  0.366474      0.366474
# 8       personal_stat_gender  0.377160      0.377160
# 2           installment_rate -0.384965      0.384965
# 10   other_installment_plans  0.403620      0.403620
# 9   other_debtors_guarantors  0.553905      0.553905
# 5                  cred_hist  0.732684      0.732684
# 12                   purpose  0.765553      0.765553
# 0                   duration -0.776286      0.776286
# 11         is_foreign_worker  0.802848      0.802848
# 4        checking_acc_status  0.889135      0.889135
# 1                   loan_amt -1.035764      1.035764

# %%
feature_importances
# Out:
# array([-0.77628625, -1.03576382, -0.38496469,  0.36647354,  0.88913532,
#         0.73268367,  0.32240105,  0.35273397,  0.37715961,  0.55390473,
#         0.40361958,  0.80284793,  0.76555256])

# %%
intercept
# Out:
# -0.3555790248415758

# %%
y_pred = pipeline.predict(X_test)
print(met.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.65        75
#            1       0.87      0.77      0.82       175
#
#     accuracy                           0.76       250
#    macro avg       0.72      0.75      0.73       250
# weighted avg       0.78      0.76      0.77       250
